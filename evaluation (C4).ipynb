# %%
import torch
from torch.utils.data import DataLoader
from transformers import AutoModelForCausalLM, AutoTokenizer, DataCollatorWithPadding
import pandas as pd
import ast
import matplotlib.pyplot as plt

# %%
def compute_fnr(results):
    count = 0
    z_list = []    
    return (results["z_score"] < 4).sum()/len(results)

def compute_fpr(results):
    count = 0
    z_list = []    
    return (results["z_score"] >= 4).sum()/len(results)

# %%
MODEL_NAME = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, cache_dir="/data1/takezawa/huggingface/", dtype=torch.float16, local_files_only=True, padding_side='left')
#model = AutoModelForCausalLM.from_pretrained(MODEL_NAME, cache_dir="/data1/takezawa/huggingface/", device_map="auto", local_files_only=True)
tokenizer.pad_token_id = 0 #model.config.pad_token_id

# %%
gamma = 0.0001

# texts generated by the NS-Watermark
results_ns_watermark = pd.read_csv(f"results/c4/z_score/ns_watermark_{gamma}_1.csv.gz")

# texts written by human
results_human = pd.read_csv(f"results/c4/z_score/human_{gamma}.csv.gz")

# %%
print(f"NS-Watermark (gamma={gamma}):")
print(f"\t FNR={compute_fnr(results_ns_watermark)}")

print("Human:")
print(f"\t FPR={compute_fpr(results_human)}")
# Out:
# NS-Watermark (gamma=0.0001):
# 	 FNR=0.0
# Human:
# 	 FPR=0.0
